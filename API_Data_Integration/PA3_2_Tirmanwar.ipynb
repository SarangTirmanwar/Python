# %%
import os
import numpy as np
import pandas as pd
import requests
import json
import altair
import csv
import time
import altair as alt

# %%
df = pd.read_csv('F:/PA3_Tirmanwar/input/csvfile.csv')

# %%
df
# Out:
#        disclosure_year disclosure_date transaction_date  owner ticker  \
# 0                 2021      10/04/2021       2021-09-27  joint     BP
# 1                 2021      10/04/2021       2021-09-13  joint    XOM
# 2                 2021      10/04/2021       2021-09-10  joint   ILPT
# 3                 2021      10/04/2021       2021-09-28  joint     PM
# 4                 2021      10/04/2021       2021-09-17   self    BLK
# ...                ...             ...              ...    ...    ...
# 15815             2020      06/10/2020       2020-04-09     --    SWK
# 15816             2020      06/10/2020       2020-04-09     --    USB
# 15817             2020      06/10/2020       2020-03-13    NaN    BMY
# 15818             2020      06/10/2020       2020-03-13    NaN    LLY
# 15819             2020      06/10/2020       2020-03-13    NaN    DIS
#
#                                        asset_description          type  \
# ...

# %%
a=df.head(170)

# %%
a
# Out:
#      disclosure_year disclosure_date transaction_date  owner ticker  \
# 0               2021      10/04/2021       2021-09-27  joint     BP
# 1               2021      10/04/2021       2021-09-13  joint    XOM
# 2               2021      10/04/2021       2021-09-10  joint   ILPT
# 3               2021      10/04/2021       2021-09-28  joint     PM
# 4               2021      10/04/2021       2021-09-17   self    BLK
# ..               ...             ...              ...    ...    ...
# 165             2021      02/25/2021       2021-01-25   self   PCAR
# 166             2021      02/25/2021       2021-01-06   self    PAG
# 167             2021      02/25/2021       2021-01-04   self     --
# 168             2021      02/25/2021       2021-01-12   self    ACN
# 169             2021      02/25/2021       2021-01-06   self     --
#
#                                      asset_description          type  \
# 0                                               BP plc      purchase
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15820 entries, 0 to 15819
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   disclosure_year         15820 non-null  int64
#  1   disclosure_date         15820 non-null  object
#  2   transaction_date        15820 non-null  object
#  3   owner                   9768 non-null   object
#  4   ticker                  15820 non-null  object
#  5   asset_description       15816 non-null  object
#  6   type                    15820 non-null  object
#  7   amount                  15820 non-null  object
#  8   representative          15820 non-null  object
#  9   district                15820 non-null  object
#  10  ptr_link                15820 non-null  object
#  11  cap_gains_over_200_usd  15820 non-null  bool
# dtypes: bool(1), int64(1), object(10)
# memory usage: 1.3+ MB

# %%
a=a.rename(columns={'cap_gains_over_200_usd': 'Capital_gains_over_200$'})

# %%
a
# Out:
#      disclosure_year disclosure_date transaction_date  owner ticker  \
# 0               2021      10/04/2021       2021-09-27  joint     BP
# 1               2021      10/04/2021       2021-09-13  joint    XOM
# 2               2021      10/04/2021       2021-09-10  joint   ILPT
# 3               2021      10/04/2021       2021-09-28  joint     PM
# 4               2021      10/04/2021       2021-09-17   self    BLK
# ..               ...             ...              ...    ...    ...
# 165             2021      02/25/2021       2021-01-25   self   PCAR
# 166             2021      02/25/2021       2021-01-06   self    PAG
# 167             2021      02/25/2021       2021-01-04   self     --
# 168             2021      02/25/2021       2021-01-12   self    ACN
# 169             2021      02/25/2021       2021-01-06   self     --
#
#                                      asset_description          type  \
# 0                                               BP plc      purchase
# ...

# %%
a=a.replace(np.nan, 0)

# %%
a
# Out:
#      disclosure_year disclosure_date transaction_date  owner ticker  \
# 0               2021      10/04/2021       2021-09-27  joint     BP
# 1               2021      10/04/2021       2021-09-13  joint    XOM
# 2               2021      10/04/2021       2021-09-10  joint   ILPT
# 3               2021      10/04/2021       2021-09-28  joint     PM
# 4               2021      10/04/2021       2021-09-17   self    BLK
# ..               ...             ...              ...    ...    ...
# 165             2021      02/25/2021       2021-01-25   self   PCAR
# 166             2021      02/25/2021       2021-01-06   self    PAG
# 167             2021      02/25/2021       2021-01-04   self     --
# 168             2021      02/25/2021       2021-01-12   self    ACN
# 169             2021      02/25/2021       2021-01-06   self     --
#
#                                      asset_description          type  \
# 0                                               BP plc      purchase
# ...

# %%
a=a.replace('--',' ')
a
# Out:
#      disclosure_year disclosure_date transaction_date  owner ticker  \
# 0               2021      10/04/2021       2021-09-27  joint     BP
# 1               2021      10/04/2021       2021-09-13  joint    XOM
# 2               2021      10/04/2021       2021-09-10  joint   ILPT
# 3               2021      10/04/2021       2021-09-28  joint     PM
# 4               2021      10/04/2021       2021-09-17   self    BLK
# ..               ...             ...              ...    ...    ...
# 165             2021      02/25/2021       2021-01-25   self   PCAR
# 166             2021      02/25/2021       2021-01-06   self    PAG
# 167             2021      02/25/2021       2021-01-04   self
# 168             2021      02/25/2021       2021-01-12   self    ACN
# 169             2021      02/25/2021       2021-01-06   self
#
#                                      asset_description          type  \
# 0                                               BP plc      purchase
# ...

# %%
for i in a['Capital_gains_over_200$']:
    if i==False:
        a['new'] = 0
    if i==True:
        a['new'] = 1
a
# Out:
#      disclosure_year disclosure_date transaction_date  owner ticker  \
# 0               2021      10/04/2021       2021-09-27  joint     BP
# 1               2021      10/04/2021       2021-09-13  joint    XOM
# 2               2021      10/04/2021       2021-09-10  joint   ILPT
# 3               2021      10/04/2021       2021-09-28  joint     PM
# 4               2021      10/04/2021       2021-09-17   self    BLK
# ..               ...             ...              ...    ...    ...
# 165             2021      02/25/2021       2021-01-25   self   PCAR
# 166             2021      02/25/2021       2021-01-06   self    PAG
# 167             2021      02/25/2021       2021-01-04   self
# 168             2021      02/25/2021       2021-01-12   self    ACN
# 169             2021      02/25/2021       2021-01-06   self
#
#                                      asset_description          type  \
# 0                                               BP plc      purchase
# ...

# %%
a = a.drop('disclosure_year', axis=1)

# %%
a
# Out:
#     disclosure_date transaction_date  owner ticker  \
# 0        10/04/2021       2021-09-27  joint     BP
# 1        10/04/2021       2021-09-13  joint    XOM
# 2        10/04/2021       2021-09-10  joint   ILPT
# 3        10/04/2021       2021-09-28  joint     PM
# 4        10/04/2021       2021-09-17   self    BLK
# ..              ...              ...    ...    ...
# 165      02/25/2021       2021-01-25   self   PCAR
# 166      02/25/2021       2021-01-06   self    PAG
# 167      02/25/2021       2021-01-04   self
# 168      02/25/2021       2021-01-12   self    ACN
# 169      02/25/2021       2021-01-06   self
#
#                                      asset_description          type  \
# 0                                               BP plc      purchase
# 1                              Exxon Mobil Corporation      purchase
# 2    Industrial Logistics Properties Trust - Common...      purchase
# 3                     Phillip Morris International Inc      purchase
# ...

# %%
b=a.head(10)
alt.Chart(b).mark_point().encode(
    y='ticker:N',
    x='owner:O',
    color='type:N'
).properties(width=700)
# Out:
# alt.Chart(...)

# %%
a.head(1)
# Out:
#   disclosure_date transaction_date  owner ticker asset_description      type  \
# 0      10/04/2021       2021-09-27  joint     BP            BP plc  purchase
#
#              amount      representative district  \
# 0  $1,001 - $15,000  Hon. Virginia Foxx     NC05
#
#                                             ptr_link  Capital_gains_over_200$  \
# 0  https://disclosures-clerk.house.gov/public_dis...                    False
#
#    new
# 0    0

# %%
alt.Chart(a).mark_bar(size=40).encode(
 alt.X("owner:N"),
 alt.Y("type:O")).properties(
    width=700,
    height=500
 )
# Out:
# alt.Chart(...)

# %%
b=a.head(10)
alt.Chart(b).mark_rect().encode(
    x='owner:O',
    y='ticker:O',
    color='type:O'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(b).mark_line().encode(
    x='transaction_date:T',
    y='type:N'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(b).mark_circle(size=60).encode(
 alt.X("ticker:N"),
 alt.Y("owner:N"),
 color='type:N',
 size='type:N'
).properties(width=400, height=350)
# Out:
# alt.Chart(...)

# %%
a.to_csv('F:/PA3_Tirmanwar/output/Output.csv')
